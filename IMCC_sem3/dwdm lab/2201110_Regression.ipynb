# %% [markdown]
# ### Name: Rahul Kumar
# ### Roll No: 2201110
#
# ## Regression

# %%
# Import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
file_path = 'C:\\Users\\ajayk\\OneDrive\\Desktop\\MCA\\kc_house_data.csv'
df = pd.read_csv(file_path)

# %%
# Display the first five observations
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# Describe the dataset
df.describe().round(2)
# Out:
#                  id       price  bedrooms  bathrooms  sqft_living    sqft_lot  \
# count  2.161300e+04    21613.00  21613.00   21613.00     21613.00    21613.00
# mean   4.580302e+09   540182.16      3.37       2.11      2079.90    15106.97
# std    2.876566e+09   367362.23      0.93       0.77       918.44    41420.51
# min    1.000102e+06    75000.00      0.00       0.00       290.00      520.00
# 25%    2.123049e+09   321950.00      3.00       1.75      1427.00     5040.00
# 50%    3.904930e+09   450000.00      3.00       2.25      1910.00     7618.00
# 75%    7.308900e+09   645000.00      4.00       2.50      2550.00    10688.00
# max    9.900000e+09  7700000.00     33.00       8.00     13540.00  1651359.00
#
#          floors  waterfront      view  condition     grade  sqft_above  \
# count  21613.00    21613.00  21613.00   21613.00  21613.00    21611.00
# mean       1.49        0.01      0.23       3.41      7.66     1788.40
# std        0.54        0.09      0.77       0.65      1.18      828.13
# min        1.00        0.00      0.00       1.00      1.00      290.00
# 25%        1.00        0.00      0.00       3.00      7.00     1190.00
# 50%        1.50        0.00      0.00       3.00      7.00     1560.00
# 75%        2.00        0.00      0.00       4.00      8.00     2210.00
# max        3.50        1.00      4.00       5.00     13.00     9410.00
#
#        sqft_basement  yr_built  yr_renovated   zipcode       lat      long  \
# count       21613.00  21613.00      21613.00  21613.00  21613.00  21613.00
# mean          291.51   1971.01         84.40  98077.94     47.56   -122.21
# std           442.58     29.37        401.68     53.51      0.14      0.14
# min             0.00   1900.00          0.00  98001.00     47.16   -122.52
# 25%             0.00   1951.00          0.00  98033.00     47.47   -122.33
# 50%             0.00   1975.00          0.00  98065.00     47.57   -122.23
# 75%           560.00   1997.00          0.00  98118.00     47.68   -122.12
# max          4820.00   2015.00       2015.00  98199.00     47.78   -121.32
#
#        sqft_living15  sqft_lot15
# count       21613.00    21613.00
# mean         1986.55    12768.46
# std           685.39    27304.18
# min           399.00      651.00
# 25%          1490.00     5100.00
# 50%          1840.00     7620.00
# 75%          2360.00    10083.00
# max          6210.00   871200.00

# %%
# Plot Pearson correlation matrix
fig_1 = plt.figure(figsize=(12, 10))
new_correlations = df.corr()
sns.heatmap(new_correlations, annot=True, cmap='Greens', annot_kws={'size': 8})
plt.title('Pearson Correlation Matrix')
plt.show()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_11072\666717142.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_correlations = df.corr()

# %%
# Determine the highest intercorrelations
highly_correlated_features = new_correlations[new_correlations > 0.75]
highly_correlated_features.fillna('-')
# Out:
#                 id price bedrooms bathrooms sqft_living sqft_lot floors  \
# id             1.0     -        -         -           -        -      -
# price            -   1.0        -         -           -        -      -
# bedrooms         -     -      1.0         -           -        -      -
# bathrooms        -     -        -       1.0    0.754665        -      -
# sqft_living      -     -        -  0.754665         1.0        -      -
# sqft_lot         -     -        -         -           -      1.0      -
# floors           -     -        -         -           -        -    1.0
# waterfront       -     -        -         -           -        -      -
# view             -     -        -         -           -        -      -
# condition        -     -        -         -           -        -      -
# grade            -     -        -         -    0.762704        -      -
# sqft_above       -     -        -         -    0.876644        -      -
# sqft_basement    -     -        -         -           -        -      -
# yr_built         -     -        -         -           -        -      -
# yr_renovated     -     -        -         -           -        -      -
# zipcode          -     -        -         -           -        -      -
# lat              -     -        -         -           -        -      -
# long             -     -        -         -           -        -      -
# sqft_living15    -     -        -         -     0.75642        -      -
# sqft_lot15       -     -        -         -           -        -      -
#
#               waterfront view condition     grade sqft_above sqft_basement  \
# id                     -    -         -         -          -             -
# price                  -    -         -         -          -             -
# bedrooms               -    -         -         -          -             -
# bathrooms              -    -         -         -          -             -
# sqft_living            -    -         -  0.762704   0.876644             -
# sqft_lot               -    -         -         -          -             -
# floors                 -    -         -         -          -             -
# waterfront           1.0    -         -         -          -             -
# view                   -  1.0         -         -          -             -
# condition              -    -       1.0         -          -             -
# grade                  -    -         -       1.0   0.755924             -
# sqft_above             -    -         -  0.755924        1.0             -
# sqft_basement          -    -         -         -          -           1.0
# yr_built               -    -         -         -          -             -
# yr_renovated           -    -         -         -          -             -
# zipcode                -    -         -         -          -             -
# lat                    -    -         -         -          -             -
# long                   -    -         -         -          -             -
# sqft_living15          -    -         -         -          -             -
# sqft_lot15             -    -         -         -          -             -
#
#               yr_built yr_renovated zipcode  lat long sqft_living15 sqft_lot15
# id                   -            -       -    -    -             -          -
# price                -            -       -    -    -             -          -
# bedrooms             -            -       -    -    -             -          -
# bathrooms            -            -       -    -    -             -          -
# sqft_living          -            -       -    -    -       0.75642          -
# sqft_lot             -            -       -    -    -             -          -
# floors               -            -       -    -    -             -          -
# waterfront           -            -       -    -    -             -          -
# view                 -            -       -    -    -             -          -
# condition            -            -       -    -    -             -          -
# grade                -            -       -    -    -             -          -
# sqft_above           -            -       -    -    -             -          -
# sqft_basement        -            -       -    -    -             -          -
# yr_built           1.0            -       -    -    -             -          -
# yr_renovated         -          1.0       -    -    -             -          -
# zipcode              -            -     1.0    -    -             -          -
# lat                  -            -       -  1.0    -             -          -
# long                 -            -       -    -  1.0             -          -
# sqft_living15        -            -       -    -    -           1.0          -
# sqft_lot15           -            -       -    -    -             -        1.0

# %%
# Remove features which are highly correlated with "sqft_living"
df = df.drop(['sqft_above', 'sqft_living15'], axis=1)

# %%
# Update features and store their length
features = df.iloc[:, 1:].columns.tolist()
len_of_features = len(features)
len_of_features
# Out:
# 18

# %%
# There are many outliers in in price
df.boxplot(column='price',notch=True,grid=False,figsize=(6,4))
plt.show()

# %%
#Price is left skewed
sns.distplot(df.price)
plt.show()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_11072\516770921.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.price)

# %%
#Sdft living is also left skewed
sns.distplot(df.sqft_living)
plt.show()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_11072\3969459294.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.sqft_living)

# %%
#Bivariate analysis
df1=df.drop(['id','zipcode','lat','long','date'],axis=1)

# %%
#To know on which all attributes does the price depend on 
sns.pairplot(df1,diag_kind='kde')

# %%
#There is a positive relation between price and grade
df1.plot(kind='scatter', x='grade',y='price',figsize=(5,5))
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
#There is a positive relation between price and sqft_;living ass well
df1.plot(kind='scatter', x='sqft_living',y='price',color='orange',figsize=(5,5))
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
#There is not much relation between price and waterfront
df1.plot(kind='scatter', x='waterfront',y='price',figsize=(5,5))
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
#There is not much relation between price and view
df1.plot(kind='scatter', x='view',y='price',figsize=(5,5))
# Out:
# <Axes: xlabel='view', ylabel='price'>
